# %%
import math
import os
from functools import reduce
from googleapiclient.discovery import build
from google.oauth2 import service_account

working_directory = os.getcwd() #the credentials.json and keys
print(os.getcwd())

def overallStudentsStatus(values):
    studentsStatusList = []

    overallScore = values
    
    for studentData in overallScore:   
        studentStatus = ""
        average = 0
        
        print("#Matricula: ", studentData[0])
        print(" Nome: ", studentData[1])
        
        numberOfAbsences = int(studentData[2])
        print("  Número de faltas: ", numberOfAbsences)
        absenceRate = round(numberOfAbsences/60,3)
        print("  Taxa de faltas/aula: ", absenceRate*100, "%")
        
        studentScore = studentData[3:]
        
        for grade in studentScore:
            print("  Nota P",studentScore.index(grade),": ", int(grade))
            average += int(grade)
        print("  Total: ", average)
        
        average /= len(studentScore)*10                          
        print("  Média: ", round(average,2))
                   
   
            
        if average < 5:
            studentStatus = "Reprovado por nota"
        elif average < 7:
            studentStatus = "Exame Final"
            #5 <= (m + naf)/2      #Less than or equal? An inequation?
            #(m + naf) >= 10   ->   naf >= 10-m
            lag = math.ceil(10 - average)
        else:
            studentStatus = "Aprovado"
            
            
        if (absenceRate > 0.25):
            studentStatus = "Reprovado por falta" 
        print("  Situação: ", studentStatus ) 
        
        
        lag = math.ceil(10 - average) if studentStatus == "Exame Final" else 0 #last aproval grade    
        print("  Nota para Aprovação Final: ", lag)
        
        print(" ")

        studentsStatusList.append([studentStatus,lag])
    
    return studentsStatusList
# Out:
# C:\Users\Samsung\Desktop\Google Sheet API

# %%
SERVICE_ACCOUNT_FILE = 'keys.json'
SCOPES = ['https://www.googleapis.com/auth/spreadsheets']

creds = None
creds = service_account.Credentials.from_service_account_file(
        SERVICE_ACCOUNT_FILE, scopes=SCOPES)


# The ID and range of a sample spreadsheet.
SAMPLE_SPREADSHEET_ID = '12ywLG_PisTSPrPmf_AmheaEnbQumGseZVx2DyXJgOZ8'


   

service = build('sheets', 'v4', credentials=creds)

# Call the Sheets API
sheet = service.spreadsheets()
result = sheet.values().get(spreadsheetId=SAMPLE_SPREADSHEET_ID,
                            range="engenharia_de_software!A4:F27").execute()

values = result.get('values', [])

request = sheet.values().update(
    spreadsheetId=SAMPLE_SPREADSHEET_ID, range="engenharia_de_software!G4",
    valueInputOption="USER_ENTERED", body={"values": overallStudentsStatus(values)}).execute()

#print(values)
# Out:
# #Matricula:  1
#  Nome:  Eduardo
#   Número de faltas:  8
#   Taxa de faltas/aula:  13.3 %
#   Nota P 0 :  35
#   Nota P 1 :  63
#   Nota P 2 :  61
#   Total:  159
#   Média:  5.3
#   Situação:  Exame Final
#   Nota para Aprovação Final:  5
#
# #Matricula:  2
#  Nome:  Murilo
#   Número de faltas:  8
#   Taxa de faltas/aula:  13.3 %
#   Nota P 0 :  64
#   Nota P 1 :  97
#   Nota P 2 :  36
#   Total:  197
#   Média:  6.57
#   Situação:  Exame Final
#   Nota para Aprovação Final:  4
#
# #Matricula:  3
#  Nome:  Guilherme
#   Número de faltas:  19
#   Taxa de faltas/aula:  31.7 %
#   Nota P 0 :  68
#   Nota P 1 :  74
#   Nota P 2 :  51
#   Total:  193
#   Média:  6.43
#   Situação:  Reprovado por falta
#   Nota para Aprovação Final:  0
#
# #Matricula:  4
#  Nome:  Flavia
#   Número de faltas:  23
#   Taxa de faltas/aula:  38.3 %
#   Nota P 0 :  66
#   Nota P 1 :  98
#   Nota P 2 :  62
#   Total:  226
#   Média:  7.53
#   Situação:  Reprovado por falta
#   Nota para Aprovação Final:  0
#
# #Matricula:  5
#  Nome:  Ruan
#   Número de faltas:  13
#   Taxa de faltas/aula:  21.7 %
#   Nota P 0 :  80
#   Nota P 1 :  65
#   Nota P 2 :  41
#   Total:  186
#   Média:  6.2
#   Situação:  Exame Final
#   Nota para Aprovação Final:  4
#
# #Matricula:  6
#  Nome:  Arnando
#   Número de faltas:  23
#   Taxa de faltas/aula:  38.3 %
#   Nota P 0 :  83
#   Nota P 1 :  68
#   Nota P 2 :  77
#   Total:  228
#   Média:  7.6
#   Situação:  Reprovado por falta
#   Nota para Aprovação Final:  0
#
# #Matricula:  7
#  Nome:  Lucas
#   Número de faltas:  5
#   Taxa de faltas/aula:  8.3 %
#   Nota P 0 :  38
#   Nota P 1 :  53
#   Nota P 2 :  80
#   Total:  171
#   Média:  5.7
#   Situação:  Exame Final
#   Nota para Aprovação Final:  5
#
# #Matricula:  8
#  Nome:  Fabio
#   Número de faltas:  10
#   Taxa de faltas/aula:  16.7 %
#   Nota P 0 :  53
#   Nota P 1 :  96
#   Nota P 2 :  89
#   Total:  238
#   Média:  7.93
#   Situação:  Aprovado
#   Nota para Aprovação Final:  0
#
# #Matricula:  9
#  Nome:  Alisson
#   Número de faltas:  15
#   Taxa de faltas/aula:  25.0 %
#   Nota P 0 :  45
#   Nota P 1 :  61
#   Nota P 2 :  68
#   Total:  174
#   Média:  5.8
#   Situação:  Exame Final
#   Nota para Aprovação Final:  5
#
# #Matricula:  10
#  Nome:  Felipe
#   Número de faltas:  12
#   Taxa de faltas/aula:  20.0 %
#   Nota P 0 :  32
#   Nota P 1 :  41
#   Nota P 2 :  85
#   Total:  158
#   Média:  5.27
#   Situação:  Exame Final
#   Nota para Aprovação Final:  5
#
# #Matricula:  11
#  Nome:  Rachel
#   Número de faltas:  11
#   Taxa de faltas/aula:  18.3 %
#   Nota P 0 :  84
#   Nota P 1 :  66
#   Nota P 2 :  39
#   Total:  189
#   Média:  6.3
#   Situação:  Exame Final
#   Nota para Aprovação Final:  4
#
# #Matricula:  12
#  Nome:  Jouy
#   Número de faltas:  13
#   Taxa de faltas/aula:  21.7 %
#   Nota P 0 :  42
#   Nota P 1 :  93
#   Nota P 2 :  57
#   Total:  192
#   Média:  6.4
#   Situação:  Exame Final
#   Nota para Aprovação Final:  4
#
# #Matricula:  13
#  Nome:  François
#   Número de faltas:  19
#   Taxa de faltas/aula:  31.7 %
#   Nota P 0 :  59
#   Nota P 1 :  87
#   Nota P 2 :  89
#   Total:  235
#   Média:  7.83
#   Situação:  Reprovado por falta
#   Nota para Aprovação Final:  0
#
# #Matricula:  14
#  Nome:  Dâmaris
#   Número de faltas:  10
#   Taxa de faltas/aula:  16.7 %
#   Nota P 0 :  44
#   Nota P 1 :  50
#   Nota P 2 :  62
#   Total:  156
#   Média:  5.2
#   Situação:  Exame Final
#   Nota para Aprovação Final:  5
#
# #Matricula:  15
#  Nome:  Leonardo
#   Número de faltas:  16
#   Taxa de faltas/aula:  26.700000000000003 %
#   Nota P 0 :  83
#   Nota P 1 :  92
#   Nota P 2 :  32
#   Total:  207
#   Média:  6.9
#   Situação:  Reprovado por falta
#   Nota para Aprovação Final:  0
#
# #Matricula:  16
#  Nome:  Guilherme
#   Número de faltas:  6
#   Taxa de faltas/aula:  10.0 %
#   Nota P 0 :  36
#   Nota P 1 :  38
#   Nota P 2 :  76
#   Total:  150
#   Média:  5.0
#   Situação:  Exame Final
#   Nota para Aprovação Final:  5
#
# #Matricula:  17
#  Nome:  Wesley
#   Número de faltas:  16
#   Taxa de faltas/aula:  26.700000000000003 %
#   Nota P 0 :  41
#   Nota P 1 :  52
#   Nota P 2 :  87
#   Total:  180
#   Média:  6.0
#   Situação:  Reprovado por falta
#   Nota para Aprovação Final:  0
#
# #Matricula:  18
#  Nome:  Yuri
#   Número de faltas:  2
#   Taxa de faltas/aula:  3.3000000000000003 %
#   Nota P 0 :  87
#   Nota P 1 :  75
#   Nota P 2 :  50
#   Total:  212
#   Média:  7.07
#   Situação:  Aprovado
#   Nota para Aprovação Final:  0
#
# #Matricula:  19
#  Nome:  Kira
#   Número de faltas:  8
#   Taxa de faltas/aula:  13.3 %
#   Nota P 0 :  36
#   Nota P 1 :  46
#   Nota P 2 :  48
#   Total:  130
#   Média:  4.33
#   Situação:  Reprovado por nota
#   Nota para Aprovação Final:  0
#
# #Matricula:  20
#  Nome:  Cleici
#   Número de faltas:  22
#   Taxa de faltas/aula:  36.7 %
#   Nota P 0 :  91
#   Nota P 1 :  88
#   Nota P 2 :  92
#   Total:  271
#   Média:  9.03
#   Situação:  Reprovado por falta
#   Nota para Aprovação Final:  0
#
# #Matricula:  21
#  Nome:  João Moacir
#   Número de faltas:  23
#   Taxa de faltas/aula:  38.3 %
#   Nota P 0 :  38
#   Nota P 1 :  90
#   Nota P 2 :  98
#   Total:  226
#   Média:  7.53
#   Situação:  Reprovado por falta
#   Nota para Aprovação Final:  0
#
# #Matricula:  22
#  Nome:  Bruno
#   Número de faltas:  15
#   Taxa de faltas/aula:  25.0 %
#   Nota P 0 :  96
#   Nota P 1 :  37
#   Nota P 2 :  100
#   Total:  233
#   Média:  7.77
#   Situação:  Aprovado
#   Nota para Aprovação Final:  0
#
# #Matricula:  23
#  Nome:  Elcio
#   Número de faltas:  9
#   Taxa de faltas/aula:  15.0 %
#   Nota P 0 :  73
#   Nota P 1 :  71
#   Nota P 2 :  75
#   Total:  219
#   Média:  7.3
#   Situação:  Aprovado
#   Nota para Aprovação Final:  0
#
# #Matricula:  24
#  Nome:  Criscia
#   Número de faltas:  0
#   Taxa de faltas/aula:  0.0 %
#   Nota P 0 :  50
#   Nota P 1 :  95
#   Nota P 2 :  84
#   Total:  229
#   Média:  7.63
#   Situação:  Aprovado
#   Nota para Aprovação Final:  0
